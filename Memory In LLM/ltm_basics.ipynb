# %% [markdown]
# # About
#
# 1. I'll learn about creation of memory stores and use of in-memory stores.

# %%
from langgraph.store.memory import InMemoryStore

# %%
store = InMemoryStore()

# %%
namespace = ('user','u1')

# %%
namespace2 = ('user','u2')

# %% [markdown]
# # Creating Memories

# %%
store.put(namespace,"1",{"data": "User Likes Pizza"})
store.put(namespace,"2" , {"data" : "User likes Pasta!"})

# %%
store.put(namespace2,"1",{"data": "User prefers I phone"})
store.put(namespace2,"2" , {"data" : "User preferred coding language is Python"})

# %% [markdown]
# # Retrieving Memories

# %%
store.get(namespace,"1")
# Out:
# Item(namespace=['user', 'u1'], key='1', value={'data': 'User Likes Pizza'}, created_at='2026-08-29T15:11:11.724902+00:00', updated_at='2026-08-29T15:11:11.724904+00:00')

# %%
store.get(namespace2,"2")
# Out:
# Item(namespace=['user', 'u2'], key='2', value={'data': 'User preferred coding language is Python'}, created_at='2026-08-29T15:11:18.212573+00:00', updated_at='2026-08-29T15:11:18.212574+00:00')
