# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearchResults(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2024 to 2026'})
results
# Out:
# C:\Users\avanindra Bose\AppData\Local\Temp\ipykernel_11880\3249493585.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# [{'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#   'url': 'https://wpexperts.io/blog/chatgpt-version-history',
#   'content': 'ChatGPT Versions\n\nRelease Date\n\nSalient Features\n\nChatGPT 5.6\n\nJune 2026\n\nGPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest).\n\nChatGPT 5.4\n\nMarch 2026\n\nIt focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. \n\nChatGPT 5.3\n\nGPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.\n\nIt improves collaboration and supports full-cycle software development. It offers more accurate answers. \n\nChatGPT 5.2\n\nDecember 2025\n\nGPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. [...] |  |  |  |\n --- \n| ChatGPT Versions | Release Date | Salient Features |\n| ChatGPT 5.6 | June 2026 | GPT-5.6 prioritizes dvanced reasoning, robust cybersecurity, and long-horizon agentic workflows. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest). |\n| ChatGPT 5.4 | March 2026 | It focuses on reasoning, agentic workflows, and coding. It supports deep web search and helps maintain context better for queries that need longer thinking. |\n| ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026. | It improves collaboration and supports full-cycle software development. It offers more accurate answers. | [...] | Scheduled Tasks in ChatGPT | January 2025 | Schedule Tasks were automated. Users could easily set up notifications, daily reports, and AI-generated messages. |\n| OpenAI o3 Preview | December 2024 | This model announced improvements in self-correction, reliability, and problem-solving. |\n| Full o1 Model Launch | December 2024 | This model was more impactful than the previous o1-preview model. Users experienced features like function calling, image analysis, and the “Reasoning Effort” parameter. |\n| Sora Launch | December 2024 | This update or release launched the “Text-to-Video Generation” feature. It helped create top-notch 20-second videos in 1080p resolution. |',
#   'score': 0.94911116},
#  {'title': 'ChatGPT Version History – Latest Releases & Future Scenario - Objects',
#   'url': 'https://objects.ws/blog/chatgpt-version-history',
#   'content': '| ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was introduced in March 2026. | This version was handy for enhancing full-cycle software development along with collaboration. It also delighted users through more accurate, logical answers. |\n| ChatGPT 5.2 | December 2025 | The version, GPT-5.2, favored routine activities and learning. Users were allowed to ask technical questions in a conversational tone. |\n| ChatGPT 5.1 | November 2025 | Answers have become smarter and conversational. GPT-5.1 Instant and GPT 5.1 Thinking were launched to provide users with more simplified and precise responses. |\n| ChatGPT 5 | August 2025 | GPT-5 demonstrated tool coordination, context management, and improved reasoning. | [...] |  |  |  |\n --- \n| ChatGPT Versions | Release Date | Crucial Features |\n| ChatGPT 5.6 | June 2026 | GPT-5.6 prioritizes long-horizon agentic workflows, advanced reasoning, and robust cybersecurity. It has three tiers: Sol (flagship), Terra (balanced), and Luna (fastest). |\n| ChatGPT 5.5 | April 2026 | The version prioritizes reasoning, agentic coding, deep research, and computer use (autonomous navigation of interfaces). |\n| ChatGPT 5.4 | March 2026 | This version valued reasoning, agentic workflows, and coding. Users were able to perform crucial tasks, such as deep web search. Moreover, it helped maintain context more effectively for queries that usually required detailed thinking. |',
#   'score': 0.94174546}]
